# %%
import librosa
import matplotlib.pyplot as plt
# ../1124.mustard_bigfile/mmsd_raw_data/Processed/audio/1_60/tmp.wav
big_file_path = '../1124.mustard_bigfile/'
video_id='1_60'
work_path = big_file_path + 'mmsd_raw_data/Processed/audio/{}/tmp.wav'.format(video_id)
y,sr = librosa.load(work_path)
print(y.shape)
plt.plot(y)
plt.show()
# Out:
# (88436,)
